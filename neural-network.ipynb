# %%
import pandas as pd

pd.read_csv('connections_clean.csv')
# Out:
#            date                     category           w1         w2       w3  \
# 0    2023-10-08        CELEBRATORY OCCASIONS  ANNIVERSARY   BIRTHDAY   SHOWER
# 1    2023-10-08           PHONE CONNECTIVITY         BARS  RECEPTION  SERVICE
# 2    2023-10-08  CITIES AND TOWNS IN ENGLAND         BATH      DERBY  READING
# 3    2023-10-08                    ___ OPERA        COMIC        MET     ROCK
# 4    2023-10-07                       RHYMES       DARREN      KAREN   SHARON
# ..          ...                          ...          ...        ...      ...
# 471  2023-06-13            LETTER HOMOPHONES          ARE      QUEUE      SEA
# 472  2023-06-12                  WET WEATHER         HAIL       RAIN    SLEET
# 473  2023-06-12                    NBA TEAMS        BUCKS       HEAT     JAZZ
# 474  2023-06-12                KEYBOARD KEYS       OPTION     RETURN    SHIFT
# 475  2023-06-12                  PALINDROMES        KAYAK      LEVEL      MOM
#
#            w4
# 0     WEDDING
# ...

# %%
476 / 4
# Out:
# 119.0
